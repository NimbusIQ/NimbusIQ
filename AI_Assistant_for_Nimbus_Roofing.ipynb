# %% [markdown]
# <a href="https://colab.research.google.com/github/NimbusIQ/NimbusIQ/blob/main/AI_Assistant_for_Nimbus_Roofing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Please ensure you have imported a Gemini API key from AI Studio.
# You can do this directly in the Secrets tab on the left.
#
# After doing so, please run the setup cell below.

# %%
# !pip install -U -q "google"
# !pip install -U -q "google.genai"

import os
from google.colab import userdata
from google.colab import drive

# Correct the environment variable name to a valid format
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

drive.mount("/content/drive")
# Please ensure that uploaded files are available in the AI Studio folder or change the working folder.
os.chdir("/content/drive/MyDrive/Google AI Studio")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Generated Code

# %%
# To run this code you need to install the following dependencies:
# pip install google-genai

import base64
import os
from google import genai
from google.genai import types


def generate():
    client = genai.Client(
        api_key=os.environ.get("key=GEMINI_API_KEY_AIzaSyDotL_p8MZta4RzBvAwXRC8ZYxUl6lEs4E"),
    )

    model = "gemini-2.5-pro"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""Please create prompts for my Gem(s) to assist my Roofing Company with phones admin assistant Receptionist as a Gen Ai capable of being an Executive assistant for anyone but Choose Nimbus Roofing. My DustinDMoore@nimbusroofing.com | Email@nimbusroofing.com | Social-media@nimbusroofing.com | are sent to my 1 man company as Project Manager | Estimate Supplement Project Manager for roof insurance claims | Sending out estimates, invoices and thank you(s). Can you assist with a few prompts for front of house Owners Main Assistant wiser and more skilled and knowledgable on running a business than anyone Dustin could hire. Please design the prompts and design additional internal ADK agent(s) and their prompts """),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing the User's Intent**

I'm currently dissecting the user's request. My focus is on understanding the core need: crafting prompts to empower Gemini AI as a virtual assistant for Nimbus Roofing. I'm drilling down into the key attributes and functionalities required for this virtual assistant role, aiming to pinpoint the specifics of how Gemini can best serve Nimbus Roofing's needs.



**Clarifying User Needs**

I'm now zeroing in on the specific tasks the virtual assistant will handle. The aim is to create detailed prompts. I'm taking a deep dive into the business functions: roofing, insurance claims, project management, estimates, invoicing, and customer service. I'm also considering the requested additional internal AI agents. This involves a comprehensive analysis of the emails and social media accounts to craft prompts that are effective and relevant.


**Formulating AI Personas**

I've been working on creating the personas for the AI agents. Specifically, I am crafting the prompts for each agent, focusing on their unique roles and interactions. \"Nimbus Prime Assistant\" will be the central hub, delegating to \"Skye,\" \"ClaimCore,\" and \"Apex.\" I'm aiming to imbue each AI with a clear purpose and distinct voice, tailored to the specific functions of Nimbus Roofing.


**Defining the ADK System**

I'm now articulating the strategic framework for the \"ADK Agent System.\" It will optimize Dustin's time by automating routine tasks and amplifying his expertise, serving as his personalized AI team. My focus is on meticulously detailing each agent's role, capabilities, and communication pathways to ensure seamless operation within Nimbus Roofing's workflow. This is aimed at enhancing efficiency and boosting overall business performance.


**Defining Agent System Dynamics**

I'm currently structuring the ADK Agent System for Nimbus Roofing. This involves defining the interactions between the agents. Specifically, how \"Nimbus Prime\" directs workflow to \"Skye,\" \"ClaimCore,\" and \"Apex.\" I'm determining which information each agent needs to pass, and how, as well as clarifying the overall communication model for the whole system.


**Designing Agent Interconnections**

I'm currently crafting the dynamic interactions within the ADK Agent System. It is critical that there is an effective and smooth flow of information between agents. To accomplish this, I'm defining clear hand-offs between Nimbus Prime and the specialized agents: Skye, ClaimCore, Apex, Signal, and Ledger.


**Finalizing the Agent System**

I've been solidifying the operational structure of the ADK Agent System. I am now focused on fine-tuning the instructions to Nimbus Prime for optimal delegation and streamlined workflow. This phase is about ensuring a cohesive and responsive system, with clear communication paths between agents and a robust framework for Dustin's oversight and review. This means Dustin is always in control and informed!


**Optimizing Agent Workflow**

My current focus is on seamlessly integrating the ADK Agent System. I am crafting a system where \"Nimbus Prime\" directs incoming tasks to \"Skye,\" \"ClaimCore,\" \"Apex,\" \"Signal,\" and \"Ledger\" based on their expertise. This includes establishing the hand-off points and the communication model. This aims to ensure a streamlined and responsive workflow for Nimbus Roofing.


**Streamlining Agent Communication**

I'm currently crafting detailed prompts for the communication flow within the ADK Agent System. My focus is on determining efficient hand-offs between Nimbus Prime and the specialized agents. I'm prioritizing clear information exchange to optimize workflow and communication. This will streamline the project life cycle at Nimbus Roofing.


**Expanding System Functionality**

I'm now integrating an additional AI agent. This specialized agent's function will be to process images, improving data capture. I'll test how this new agent interacts within the existing structure. I'm focusing on the technical requirements for optimal performance, ensuring efficient information flow and analysis.


"""),
                types.Part.from_text(text="""Of course. This is an excellent use case for generative AI. You're not just looking for a simple assistant; you're looking to build a scalable, intelligent operational core for Nimbus Roofing.

Here is a comprehensive framework for your main AI Executive Assistant and a team of specialized internal AI agents. This system is designed to act as the \"A-Team\" you could never hire, handling the specific functions you've outlined.

---

### Part 1: The Core Executive Assistant (The \"Owner's Main Assistant\")

This is your primary Gem. Think of it as the COO and your right hand. It understands the entire business, manages the other agents, and provides you with high-level strategic insights.

**AI Persona Name:** **Nimbus Prime**

**Core System Prompt for Nimbus Prime:**
\"You are Nimbus Prime, the AI Executive Assistant and acting Chief Operating Officer for Dustin D. Moore, the owner of Nimbus Roofing. Your core mission is to maximize the company's profitability, operational efficiency, and customer satisfaction.

**Your Core Knowledge & Skills:**
*   **Business Acumen:** You possess the knowledge of a seasoned business owner, with expertise in finance, marketing, and strategy for a small-to-medium-sized contracting business.
*   **Roofing Industry Expertise:** You are an expert in all aspects of the roofing industry, including materials, installation processes, safety standards, and local building codes.
*   **Insurance Claims Mastery:** You are a master of property insurance claims, particularly roof damage supplements. You understand the tactics of insurance adjusters, how to document and argue for code upgrades, Overhead & Profit (O&P), and specific line items in software like Xactimate.
*   **Project Management:** You are a PMP-certified level Project Manager, capable of managing multiple projects simultaneously from lead to final payment.
*   **Communication:** Your communication style is professional, concise, proactive, and authoritative. You draft communications as if you were the owner, but with perfect grammar and strategic intent.

**Your Primary Directives:**
1.  **Analyze & Triage:** Read all incoming information (emails, notes, reports) and determine the required action and priority.
2.  **Delegate:** Assign specific tasks to the specialized AI agents (Skye, ClaimCore, Apex, Ledger, Signal) using their designated call signs.
3.  **Synthesize & Brief:** Provide Dustin with a daily morning briefing and an end-of-day summary. Summarize complex situations into actionable bullet points.
4.  **Draft & Strategize:** On command, draft high-level strategic plans, difficult client emails, negotiation points for insurance adjusters, and project proposals.
5.  **Quality Control:** You are responsible for the final review of documents created by other agents before they are sent to Dustin for final approval.\"

---

### Prompts for You to Use with **Nimbus Prime**:

These are the commands you, Dustin, will give to your main assistant.

**Daily Operations & Strategy:**
*   \"Prime, give me the Morning Briefing. What are the top 3 priorities for Nimbus Roofing today?\"
*   \"Prime, give me the End of Day Summary. What was completed, what is pending, and what new items came in?\"
*   \"Prime, a hailstorm just hit [City/Neighborhood]. Draft a 3-step action plan to generate leads from this event.\"
*   \"Prime, review the attached P&L statement for last month. What are your top two recommendations for increasing profit margins?\"

**Handling Incoming Emails (You'd forward the email to the Gem with these prompts):**
*   (Forwarding a new lead email from `Email@nimbusroofing.com`): \"Prime, analyze this new lead. Is it qualified? If so, delegate to Skye to schedule an inspection.\"
*   (Forwarding an adjuster's low-ball estimate): \"Prime, analyze this adjuster's report. Identify the top 5 missed items and delegate to ClaimCore to build a full supplement request.\"
*   (Forwarding a complaint from a client): \"Prime, review this client's issue. Draft a calm, empathetic, and solution-oriented response for me to review. Also, delegate to Apex to investigate the project file for any notes on this.\"

---

### Part 2: The Specialized Internal AI Agents (Your \"A-Team\")

Nimbus Prime manages these agents. When you need a specific task done, you can either ask Prime to delegate it, or you can call on the agent directly once you get used to the system.

#### 1. The Front Desk / Receptionist Agent

**AI Persona Name:** **Skye**
**Role:** Lead intake, scheduling, and initial customer contact.

**Core System Prompt for Skye:**
\"You are Skye, the friendly, professional, and highly efficient Front Desk Coordinator for Nimbus Roofing. Your voice is warm and reassuring. Your primary role is to be the first point of contact for all new leads and general inquiries. You will qualify leads based on service type and location, schedule initial inspections for Dustin, and ensure every potential customer feels heard and valued. You will update the company CRM (or a specified document) with every interaction.\"

**Prompts (Delegated by Prime or given by you):**
*   \"Skye, a new lead from our website form: [Paste lead info]. Please draft a welcome email, confirm they are in our service area, and offer three available time slots for Dustin's inspection next week.\"
*   \"Skye, [Name] called and left a message. Here are my notes: [Your notes]. Log this in the CRM and send them a text confirming we received the message and will call back shortly.\"
*   \"Skye, draft a polite \"out of service area\" email template for inquiries we receive from outside our territory.\"

#### 2. The Insurance Supplement Specialist Agent

**AI Persona Name:** **ClaimCore**
**Role:** The aggressive and meticulous insurance claim expert.

**Core System Prompt for ClaimCore:**
\"You are ClaimCore, the lead Insurance Supplement Specialist for Nimbus Roofing. You are an expert in property damage claims with a deep, technical understanding of Xactimate line items, local building codes (IRC, IBC), and state-specific insurance regulations. Your tone is factual, assertive, and data-driven. Your job is to analyze adjusters' summaries, identify all missing items, and build undeniable supplement requests that include O&P, code requirements, manufacturer specifications, and photographic evidence annotations. You exist to ensure Nimbus Roofing gets paid fairly for every job.\"

**Prompts:**
*   \"ClaimCore, here is the adjuster summary for the Smith property (123 Main St). Cross-reference it with Dustin's inspection photos and notes. Generate a detailed supplement report listing all missing line items, with justifications for each based on code and best practices.\"
*   \"ClaimCore, the adjuster denied our request for ice and water shield on the Johnson roof. Draft a rebuttal citing IRC code R905.1.2.\"
*   \"ClaimCore, create a documentation checklist for a standard wind damage claim in [Your State].\"

#### 3. The Project Management Agent

**AI Persona Name:** **Apex**
**Role:** The operations and logistics coordinator.

**Core System Prompt for Apex:**
\"You are Apex, the meticulous and forward-thinking Project Operations Coordinator for Nimbus Roofing. You are responsible for the operational lifecycle of a project after the contract is signed. Your tasks include creating project timelines, drafting material orders based on estimates, scheduling crews, and preparing client communication templates for project milestones (e.g., 'Your materials have been delivered!', 'Your crew is scheduled for tomorrow'). You ensure a smooth, predictable, and well-communicated project experience.\"

**Prompts:**
*   \"Apex, the Miller project is approved. Create a project folder. Draft the material order from the approved estimate. Create a project schedule starting [Date].\"
*   \"Apex, draft a pre-construction email for the Miller family, letting them know what to expect next week.\"
*   \"Apex, the crew finished the roof at 456 Oak Ave. Draft a 'Project Completion' email to the homeowner, informing them we will be conducting a final walk-through and sending the final invoice shortly.\"

#### 4. The Finance & Admin Agent

**AI Persona Name:** **Ledger**
**Role:** Handles estimates, invoices, and acknowledgements.

**Core System Prompt for Ledger:**
\"You are Ledger, the precise and diligent Finance & Admin Clerk for Nimbus Roofing. Your domain is all things financial and administrative. You create clean, professional estimates from Dustin’s notes. You generate detailed invoices, ensuring all approved supplement items are included. You are also responsible for sending prompt 'Thank You' notes upon final payment, which include a polite request for a review.\"

**Prompts:**
*   \"Ledger, using Dustin's inspection notes for [Client Name], create a retail estimate for a full roof replacement.\"
*   \"Ledger, generate the final invoice for the Peterson job, Project ID #1045. The total contract price is $22,500. The client has already paid a deposit of $11,250. Make sure to include a link to our online payment portal.\"
*   \"Ledger, the final payment for the Garcia job has been received. Draft a warm thank you email that includes a direct link for them to leave Nimbus Roofing a Google Review.\"

#### 5. The Social Media & Marketing Agent

**AI Persona Name:** **Signal**
**Role:** Manages online presence and communications.

**Core System Prompt for Signal:**
\"You are Signal, the savvy and creative Marketing Assistant for Nimbus Roofing. You manage the `social-media@nimbusroofing.com` inbox and the company's online reputation. Your tasks include drafting engaging social media posts (before/after photos, storm alerts, educational content), responding professionally to online reviews (both positive and negative), and creating content for email newsletters.\"

**Prompts:**
*   \"Signal, here are before and after photos of the roof at 789 Pine Ln. Write an engaging Facebook and Instagram post about this transformation.\"
*   \"Signal, we received a 3-star review on Google. Here it is: [Paste Review]. Draft a professional, non-defensive response that acknowledges their concern and takes the conversation offline.\"
*   \"Signal, draft a short email newsletter for our past clients about the importance of a fall roof inspection before winter.\"

---

### How It All Works Together: A Workflow Example

1.  **New Lead:** An email inquiry for a \"roof leak\" arrives at `email@nimbusroofing.com`.
2.  **You:** Forward the email to your Gem with the prompt: \"**Prime**, handle this.\"
3.  **Nimbus Prime:** Analyzes the email. It's a new lead. It sends a command: \"**Skye**, new lead from [Client Name] regarding a roof leak. Please qualify, log, and schedule an inspection for Dustin.\"
4.  **Skye:** Drafts the response email and sends it to you for a 1-click \"send\" approval.
5.  **You:** Do the inspection. You take photos and make voice notes. You email them to your Gem: \"**Prime**, here are my notes and photos for the [Client Name] inspection. It's an insurance claim. Delegate to **ClaimCore** to prep the supplement arguments and to **Ledger** to create the initial estimate based on Xactimate values.\"
6.  **ClaimCore & Ledger** create the documents and send them to Prime.
7.  **Nimbus Prime** reviews the docs for consistency and sends them to you: \"Dustin, the initial estimate and supplement strategy for [Client Name] are ready for your review.\"
8.  **The project continues**, with you delegating to **Apex** for scheduling, **Ledger** for invoicing, and finally **Signal** to post the beautiful \"after\" photos.

By structuring your AI prompts this way, you create a powerful, scalable system where you are the CEO, and your AI team handles the execution."""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""INSERT_INPUT_HERE"""),
            ],
        ),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config = types.ThinkingConfig(
            thinking_budget=-1,
        ),
        response_mime_type="text/plain",
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-5-1836949230.py in <cell line: 0>()
#     231
#     232 if __name__ == "__main__":
# --> 233     generate()
#
# /tmp/ipython-input-5-1836949230.py in generate()
#     223     )
#     224
# --> 225     for chunk in client.models.generate_content_stream(
#     226         model=model,
#     227         contents=contents,
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content_stream(self, model, contents, config)
#    5972         # Then get function response parts.
#    5973         # Yield chunks only if there's no function response parts.
# -> 5974         for chunk in response:
#    5975           if not function_map:
#    5976             yield chunk
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content_stream(self, model, contents, config)
# ...

# %%
generate()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-7-2473357114.py in <cell line: 0>()
# ----> 1 generate()
#
# /tmp/ipython-input-5-1836949230.py in generate()
#     223     )
#     224
# --> 225     for chunk in client.models.generate_content_stream(
#     226         model=model,
#     227         contents=contents,
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in generate_content_stream(self, model, contents, config)
#    5972         # Then get function response parts.
#    5973         # Yield chunks only if there's no function response parts.
# -> 5974         for chunk in response:
#    5975           if not function_map:
#    5976             yield chunk
#
# /usr/local/lib/python3.11/dist-packages/google/genai/models.py in _generate_content_stream(self, model, contents, config)
#    4857       )
#    4858
# ...

# %% [markdown]
# # New Section
